# %%
# superposition.ipynb

import numpy as np
from IPython.display import display
from qis102_utils import as_latex
from qiskit import QuantumCircuit, transpile
from qiskit.visualization import (
    plot_bloch_multivector,
    plot_distribution,
    plot_histogram,
)
from qiskit_aer import AerSimulator

# Cell 1 - One qubit on Z basis

qc = QuantumCircuit(1)
qc.initialize([0, 1], 0) # pass in a state vector and initialize it to a qubit
qc.save_statevector("sv1")
qc.x(0)
qc.save_statevector("sv2")
qc.measure_all()  # measure all- measures the qubit onto one classical boolean bit

display(qc.draw(output="mpl"))

backend = AerSimulator()
qc_transpiled = transpile(qc, backend)
result = backend.run(qc_transpiled).result()

sv1 = result.data(0)["sv1"]
sv2 = result.data(0)["sv2"]

display(as_latex(sv1, prefix=r"\mathbf{Statevector\;1}="))
display(plot_bloch_multivector(sv1))
display(as_latex(sv2, prefix=r"\mathbf{Statevector\;2}="))
display(plot_bloch_multivector(sv2))

counts = result.get_counts(qc)
display(plot_distribution(counts))
# Out:
# $\displaystyle \mathbf{Statevector\;1}=\begin{bmatrix}0 &1\\\end{bmatrix}$
# $\displaystyle \mathbf{Statevector\;2}=\begin{bmatrix}1 &0\\\end{bmatrix}$

# %%
# Cell 2 - One qubit NOT on Z basis

qc = QuantumCircuit(1)
qc.initialize([0.5, np.sqrt(3) / 2], 0)
qc.save_statevector("sv1")
qc.x(0)
qc.save_statevector("sv2")
qc.measure_all()

display(qc.draw(output="mpl"))
backend = AerSimulator()
qc_transpiled = transpile(qc, backend)
result = backend.run(qc_transpiled).result()

sv1 = result.data(0)["sv1"]
sv2 = result.data(0)["sv2"]

display(as_latex(sv1, prefix=r"\mathbf{Statevector\;1}="))
display(plot_bloch_multivector(sv1))
display(as_latex(sv2, prefix=r"\mathbf{Statevector\;2}="))
display(plot_bloch_multivector(sv2))

counts = result.get_counts(qc)
display(plot_distribution(counts))
# Out:
# $\displaystyle \mathbf{Statevector\;1}=\begin{bmatrix}\frac{1}{2} &\frac{\sqrt{3}}{2}\\\end{bmatrix}$
# $\displaystyle \mathbf{Statevector\;2}=\begin{bmatrix}\frac{\sqrt{3}}{2} &\frac{1}{2}\\\end{bmatrix}$

# %%
# Cell 3 - One Pete Box
# "Pete box": drop in a white or black marble: will come out 50 50 white or black
# if you stack two pete boxes on top of each other, it will come out whatever color it was dropped in as
# really a hadamard gate

qc = QuantumCircuit(1)
qc.initialize([0, 1], 0)
qc.save_statevector("sv1")
qc.h(0) # hadamard gate
qc.save_statevector("sv2")
qc.measure_all()

display(qc.draw(output="mpl"))
backend = AerSimulator()
qc_transpiled = transpile(qc, backend)
result = backend.run(qc_transpiled).result()

sv1 = result.data(0)["sv1"]
sv2 = result.data(0)["sv2"]

display(as_latex(sv1, prefix=r"\mathbf{Statevector\;1}="))
display(plot_bloch_multivector(sv1))
display(as_latex(sv2, prefix=r"\mathbf{Statevector\;2}="))
display(plot_bloch_multivector(sv2))

counts = result.get_counts(qc)
display(plot_distribution(counts))
# Out:
# $\displaystyle \mathbf{Statevector\;1}=\begin{bmatrix}0 &1\\\end{bmatrix}$
# $\displaystyle \mathbf{Statevector\;2}=\begin{bmatrix}\frac{1}{\sqrt{2}} &-\frac{1}{\sqrt{2}}\\\end{bmatrix}$

# %%
# Cell 4 - Two Pete Boxes
# Note: This demonstrates the Hadamard Gate is Unitary

qc = QuantumCircuit(1)
qc.initialize([0, 1], 0)
qc.save_statevector("sv1")
qc.h(0)
qc.save_statevector("sv2")
qc.h(0)
qc.save_statevector("sv3")
qc.measure_all()

display(qc.draw(output="mpl"))
backend = AerSimulator()
qc_transpiled = transpile(qc, backend)
result = backend.run(qc_transpiled).result()

sv1 = result.data(0)["sv1"]
sv2 = result.data(0)["sv2"]
sv3 = result.data(0)["sv3"]

display(as_latex(sv1, prefix=r"\mathbf{Statevector\;1}="))
display(plot_bloch_multivector(sv1))
display(as_latex(sv2, prefix=r"\mathbf{Statevector\;2}="))
display(plot_bloch_multivector(sv2))
display(as_latex(sv3, prefix=r"\mathbf{Statevector\;2}="))
display(plot_bloch_multivector(sv3))

counts = result.get_counts(qc)
display(plot_distribution(counts))
# Out:
# $\displaystyle \mathbf{Statevector\;1}=\begin{bmatrix}0 &1\\\end{bmatrix}$
# $\displaystyle \mathbf{Statevector\;2}=\begin{bmatrix}\frac{1}{\sqrt{2}} &-\frac{1}{\sqrt{2}}\\\end{bmatrix}$
# $\displaystyle \mathbf{Statevector\;2}=\begin{bmatrix}0 &1\\\end{bmatrix}$

# %%
# Cell 5 - Gate Equivalence (no measurement)
# This demonstrates the identity X = HZH

qc = QuantumCircuit(1)
qc.initialize([0, 1], 0)
qc.save_statevector("sv1")
qc.h(0)
qc.save_statevector("sv2")
qc.z(0)
qc.save_statevector("sv3")
qc.h(0)
qc.save_statevector("sv4")

display(qc.draw(output="mpl"))
backend = AerSimulator()
qc_transpiled = transpile(qc, backend)
result = backend.run(qc_transpiled).result()

sv1 = result.data(0)["sv1"]
sv2 = result.data(0)["sv2"]
sv3 = result.data(0)["sv3"]
sv4 = result.data(0)["sv4"]

display(as_latex(sv1, prefix=r"\mathbf{Statevector\;1}="))
display(plot_bloch_multivector(sv1))
display(as_latex(sv2, prefix=r"\mathbf{Statevector\;2}="))
display(plot_bloch_multivector(sv2))
display(as_latex(sv3, prefix=r"\mathbf{Statevector\;3}="))
display(plot_bloch_multivector(sv3))
display(as_latex(sv4, prefix=r"\mathbf{Statevector\;4}="))
display(plot_bloch_multivector(sv4))
# Out:
# $\displaystyle \mathbf{Statevector\;1}=\begin{bmatrix}0 &1\\\end{bmatrix}$
# $\displaystyle \mathbf{Statevector\;2}=\begin{bmatrix}\frac{1}{\sqrt{2}} &-\frac{1}{\sqrt{2}}\\\end{bmatrix}$
# $\displaystyle \mathbf{Statevector\;3}=\begin{bmatrix}\frac{1}{\sqrt{2}} &\frac{1}{\sqrt{2}}\\\end{bmatrix}$
# $\displaystyle \mathbf{Statevector\;4}=\begin{bmatrix}1 &0\\\end{bmatrix}$

# %%
# Cell 6 - One qubit circuit not on basis (10 shots)

qc = QuantumCircuit(1)
qc.initialize([0.5, np.sqrt(3) / 2], 0)
qc.x(0)
qc.measure_all()

display(qc.draw(output="mpl"))
backend = AerSimulator()
qc_transpiled = transpile(qc, backend)
result = backend.run(qc_transpiled, shots=10).result()
counts = result.get_counts(qc)
display(plot_histogram(counts))

# %%
# Cell 7 - One qubit circuit not on basis (10,000 shots)

qc = QuantumCircuit(1)
qc.initialize([0.5, np.sqrt(3) / 2], 0)
qc.x(0)
qc.measure_all()

backend = AerSimulator()
qc_transpiled = transpile(qc, backend)
result = backend.run(qc_transpiled, shots=100_000).result()
counts = result.get_counts(qc)
display(plot_distribution(counts))
